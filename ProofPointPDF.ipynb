# %% [markdown]
# <a href="https://colab.research.google.com/github/ignisdigitalarcade/Verse/blob/main/ProofPointPDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install unstructured  
# !pip install openai
# !pip install pybind11 
# !pip install chromadb
# !pip install Cython
# !pip3 install "git+https://github.com/philferriere/cocoapi.git#egg=pycocotools&subdirectory=PythonAPI" 
# !pip install unstructured[local-inference]
# !CC=clang CXX=clang++ ARCHFLAGS="-arch x86_64" pip install 'git+https://github.com/facebookresearch/detectron2.git' 
# !pip install layoutparser[layoutmodels,tesseract] 
# !pip install pytesseract 
# !pip install Pillow==9.0.0 
# !pip install tiktoken
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.3/939.3 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 51.3 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator

# %%
from detectron2.config import get_cfg
cfg = get_cfg()    
cfg.MODEL.DEVICE = 'gpu'

# %%
# !wget https://farmfuel.tech/wp-content/uploads/2023/05/Grant.pdf
# Out:
# --2023-05-29 22:39:43--  https://farmfuel.tech/wp-content/uploads/2023/05/Grant.pdf
# Resolving farmfuel.tech (farmfuel.tech)... 160.153.0.93
# Connecting to farmfuel.tech (farmfuel.tech)|160.153.0.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1910042 (1.8M) [application/pdf]
# Saving to: ‘Grant.pdf’
#
# Grant.pdf           100%[===================>]   1.82M  --.-KB/s    in 0.1s
#
# 2023-05-29 22:39:44 (14.9 MB/s) - ‘Grant.pdf’ saved [1910042/1910042]

# %%
# !mkdir docs
# !mv Grant.pdf docs

# %%
text_folder = 'docs'
loaders = [UnstructuredPDFLoader(os.path.join(text_folder, fn)) for fn in os.listdir(text_folder)]

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 174 kB of archives.
# After this operation, 754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.1 [174 kB]
# Fetched 174 kB in 1s (225 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 122545 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.1_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.1) ...
# Setting up poppler-utils (0.86.1-0ubuntu1.1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
index = VectorstoreIndexCreator().from_loaders(loaders)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
query = "In 500 words, explain the successful factors in this grant proposal from SolarSteam"
index.query(query)
