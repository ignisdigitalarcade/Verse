# %% [markdown]
# <a href="https://colab.research.google.com/github/ignisdigitalarcade/Verse/blob/main/sagaxdoc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install unstructured  
# !pip install openai
# !pip install pybind11 
# !pip install chromadb
# !pip install Cython
# !pip3 install "git+https://github.com/philferriere/cocoapi.git#egg=pycocotools&subdirectory=PythonAPI" 
# !pip install unstructured[local-inference]
# !CC=clang CXX=clang++ ARCHFLAGS="-arch x86_64" pip install 'git+https://github.com/facebookresearch/detectron2.git' 
# !pip install layoutparser[layoutmodels,tesseract] 
# !pip install pytesseract 
# !pip install Pillow==9.0.1 
# !pip install tiktoken
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 38.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 6.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 79.6 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator

# %%
from detectron2.config import get_cfg
cfg = get_cfg()    
cfg.MODEL.DEVICE = 'gpu'

# %%
# !wget https://farmfuel.tech/wp-content/uploads/2023/06/QuantumThermodynamics.pdf
# Out:
# --2023-06-06 00:40:32--  https://farmfuel.tech/wp-content/uploads/2023/06/QuantumThermodynamics.pdf
# Resolving farmfuel.tech (farmfuel.tech)... 160.153.0.93
# Connecting to farmfuel.tech (farmfuel.tech)|160.153.0.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4130034 (3.9M) [application/pdf]
# Saving to: ‘QuantumThermodynamics.pdf’
#
# QuantumThermodynami 100%[===================>]   3.94M  24.5MB/s    in 0.2s
#
# 2023-06-06 00:40:32 (24.5 MB/s) - ‘QuantumThermodynamics.pdf’ saved [4130034/4130034]

# %%
# !mkdir docs
# !mv QuantumThermodynamics.pdf docs

# %%
text_folder = 'docs'
loaders = [UnstructuredPDFLoader(os.path.join(text_folder, fn)) for fn in os.listdir(text_folder)]

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 174 kB of archives.
# After this operation, 754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.1 [174 kB]
# Fetched 174 kB in 0s (360 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 122542 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.1_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.1) ...
# Setting up poppler-utils (0.86.1-0ubuntu1.1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
index = VectorstoreIndexCreator().from_loaders(loaders)

# %%
query = "Summarize chapter three Thermodynamics of Quantum Information in 1000 words in QuantumThermodynamics.pdf"
index.query(query)
# Out:
# ' Chapter three of Quantum Thermodynamics introduces the reader to the thermodynamics of quantum information processing. It begins by discussing the thermodynamic implications of quantum computing, including the energy cost of quantum operations and the role of entropy in quantum computing. It then moves on to discuss the thermodynamics of quantum information processing, including the role of entanglement in quantum computing, the thermodynamic cost of quantum information processing, and the implications of quantum thermodynamics for the development of quantum technologies. Finally, the chapter concludes with a discussion of some of the more state-of-the-art topics in this rapidly developing research field, such as the thermodynamics of quantum error correction and the thermodynamics of quantum communication.'

# %%
query = "What are the variables and conditions for measuring the cost of energy from quantum operations entropy in quantum computing from chapter three from QuantumThermodynamics.pdf?"
index.query(query)
# Out:
# ' The two-time energy measurement approach is used to measure the cost of energy from quantum operations entropy in quantum computing. This approach involves measuring the energy of an isolated quantum system that evolves under the time-dependent Schrödinger equation. The variables used in this approach are the energy of the quantum system and the time-dependent Hamiltonian.'
